# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('../tmp.csv',delimiter=",",index_col=None,
                   engine='python')

# %%
df
# Out:
#          CELL TIME DDR1 PAX8 RPS5 ABCF1 SPAG7 RHOA RNPS1 SMNDC1  ...   P4HTM  \
# 0        A375  24H    B    D    B     C     C    C     C      C  ...       D
# 1        A549  24H    B    C    C     C     E    C     C      C  ...       C
# 2       HEPG2  24H    E    C    D     C     C    D     C      C  ...       C
# 3      HS578T   3H    D    C    C     C     C    C     C      C  ...       D
# 4        HT29  24H    D    C    C     D     D    C     C      A  ...       E
# 5      MCF10A  24H    D    C    C     C     D    B     A      A  ...       D
# 6    MDAMB231  24H    E    C    D     B     B    C     A      B  ...       C
# 7      HCC515  24H    A    C    A     C     C    C     B      C  ...       C
# 8      HCC515  24H    B    C    C     C     B    C     C      C  ...       D
# 9       HEPG2  24H    D    D    D     C     C    E     D      A  ...       E
# 10       HME1   3H    D    C    C     C     D    D     C      B  ...       D
# ...

# %%
Z=['B','C']
str1='DDR1'

# %%
for val in Z:
    df=df[df.eval(str1) != val]
df
# Out:
#          CELL TIME DDR1 PAX8 RPS5 ABCF1 SPAG7 RHOA RNPS1 SMNDC1  ...   P4HTM  \
# 2       HEPG2  24H    E    C    D     C     C    D     C      C  ...       C
# 3      HS578T   3H    D    C    C     C     C    C     C      C  ...       D
# 4        HT29  24H    D    C    C     D     D    C     C      A  ...       E
# 5      MCF10A  24H    D    C    C     C     D    B     A      A  ...       D
# 6    MDAMB231  24H    E    C    D     B     B    C     A      B  ...       C
# 7      HCC515  24H    A    C    A     C     C    C     B      C  ...       C
# 9       HEPG2  24H    D    D    D     C     C    E     D      A  ...       E
# 10       HME1   3H    D    C    C     C     D    D     C      B  ...       D
# 11       HME1   3H    D    E    C     D     E    E     D      A  ...       E
# 12     HS578T  24H    E    C    C     C     D    A     B      C  ...       D
# 13       MCF7   3H    A    C    C     C     C    C     C      C  ...       C
# ...

# %%
df.eval(str1)
# Out:
# 3      E
# 4      D
# 5      E
# 6      D
# 7      D
# 8      D
# 9      E
# 10     D
# 12     E
# 13     E
# 14     E
# 15     D
# 17     D
# 19     E
# 20     D
# 25     A
# 27     D
# 28     D
# 29     E
# 30     D
# 31     E
# 32     D
# 33     D
# 34     D
# 36     A
# 38     D
# 40     E
# 41     D
# 42     E
# 45     E
#       ..
# 257    D
# 258    E
# 259    A
# 260    D
# 262    D
# 264    E
# 265    D
# 266    E
# 267    D
# 268    E
# 269    D
# 270    D
# 271    D
# 272    D
# 273    D
# 274    E
# 275    E
# 276    D
# 277    D
# 278    D
# 279    D
# 280    E
# 282    D
# 283    D
# 284    D
# 286    E
# 289    E
# 290    D
# 291    D
# 292    D
# Name: DDR1, Length: 199, dtype: object

# %%
df.EGFR
# Out:
# 0      E
# 1      E
# 2      E
# 3      D
# 4      B
# 5      E
# 6      A
# 7      E
# 8      D
# 9      D
# 10     B
# 11     D
# 12     B
# 13     B
# 14     B
# 15     A
# 16     B
# 17     A
# 18     D
# 19     E
# 20     B
# 21     B
# 22     B
# 23     D
# 24     B
# 25     D
# 26     D
# 27     A
# 28     B
# 29     B
#       ..
# 77     E
# 78     D
# 79     E
# 80     D
# 81     E
# 82     B
# 83     D
# 84     B
# 85     E
# 86     D
# 87     B
# 88     E
# 89     E
# 90     D
# 91     E
# 92     B
# 93     A
# 94     A
# 95     B
# 96     D
# 97     E
# 98     A
# 99     D
# 100    B
# 101    B
# 102    A
# 103    D
# 104    E
# 105    B
# 106    D
# Name: EGFR, Length: 107, dtype: object

# %%
import operator
x = {1: 2, 3: 4, 4: 3, 2: 1, 0: 0}
sorted_x = sorted(x.items(), key=operator.itemgetter(1))

# %%
sorted_x[-1][1]
# Out:
# 4

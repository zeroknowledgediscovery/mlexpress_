# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 36}

mpl.rc('font', **font)

# %%
df=pd.read_csv('out_1.txt',delimiter=",",index_col=None,
                   engine='python')

# %%
df
# Out:
#          CELL TIME DDR1 PAX8 RPS5 ABCF1 SPAG7 RHOA RNPS1 SMNDC1  ...   P4HTM  \
# 0        A375  24H    B    D    B     C     C    C     C      C  ...       D
# 1        A549  24H    B    C    C     C     E    C     C      C  ...       C
# 2        BT20  24H    B    C    C     C     C    B     D      C  ...       E
# 3        BT20  24H    E    C    C     C     C    E     C      A  ...       E
# 4        BT20   3H    D    B    C     C     C    C     C      C  ...       D
# 5       HEPG2  24H    E    C    D     C     C    D     C      C  ...       C
# 6      HS578T  24H    D    C    C     C     C    C     C      C  ...       C
# 7      HS578T   3H    D    C    C     C     C    C     C      C  ...       D
# 8        HT29  24H    D    C    C     D     D    C     C      A  ...       E
# 9      MCF10A  24H    E    C    D     C     D    C     A      A  ...       D
# 10     MCF10A  24H    D    C    C     C     D    B     A      A  ...       D
# 11   MDAMB231  24H    B    C    C     C     C    C     C      C  ...       C
# 12   MDAMB231  24H    E    C    D     B     B    C     A      B  ...       C
# 13   MDAMB231  24H    E    C    C     C     C    C     C      C  ...       C
# 14        PC3  24H    E    C    D     C     D    B     B      B  ...       E
# 15        PC3  24H    D    D    D     C     C    E     C      C  ...       D
# 16      SKBR3  24H    B    C    C     C     C    C     C      C  ...       C
# 17      SKBR3  24H    D    B    C     A     C    C     C      C  ...       C
# 18       A375  24H    B    C    C     C     C    B     D      D  ...       C
# 19       A549  24H    E    E    B     E     C    A     C      D  ...       E
# 20       A549  24H    D    E    C     C     C    D     B      C  ...       C
# 21       BT20   3H    B    C    C     C     B    C     C      C  ...       C
# 22       BT20   3H    B    C    C     C     C    C     C      C  ...       C
# 23       BT20   3H    B    C    C     C     C    C     C      C  ...       C
# 24       HA1E  24H    B    C    C     C     C    C     C      C  ...       C
# 25     HCC515  24H    A    C    A     C     C    C     B      C  ...       C
# 26     HCC515  24H    B    C    C     C     B    C     C      C  ...       D
# 27      HEPG2  24H    D    D    D     C     C    E     D      A  ...       E
# 28       HME1   3H    D    C    C     C     D    D     C      B  ...       D
# 29       HME1   3H    E    C    D     D     D    E     E      C  ...       C
# ..        ...  ...  ...  ...  ...   ...   ...  ...   ...    ...  ...     ...
# 264      HELA  24H    E    C    C     C     C    C     C      C  ...       C
# 265      HT29  24H    D    C    C     C     C    C     C      C  ...       D
# 266      HT29  24H    E    C    B     D     C    C     C      C  ...       D
# 267      A375  24H    D    C    C     C     C    B     C      C  ...       C
# 268      HELA  24H    E    C    C     C     C    B     A      C  ...       C
# 269       PC3  24H    D    C    C     C     C    C     C      C  ...       C
# 270       PC3  24H    D    B    C     C     C    C     E      C  ...       C
# 271       PC3  24H    D    C    C     C     C    C     C      C  ...       C
# 272       PC3  24H    D    B    C     E     C    B     C      C  ...       C
# 273       PC3  24H    D    C    B     C     C    C     D      C  ...       C
# 274      YAPC  24H    E    C    D     C     C    B     C      C  ...       E
# 275      HA1E  24H    E    E    C     E     C    A     A      E  ...       A
# 276      HELA  24H    D    D    C     C     E    C     C      C  ...       B
# 277      HELA  24H    D    D    C     D     E    C     B      E  ...       C
# 278      HELA  24H    D    C    B     C     C    C     C      C  ...       C
# 279      HT29  24H    D    C    B     D     D    C     C      C  ...       A
# 280      HT29  24H    E    D    C     C     E    C     A      E  ...       D
# 281      MCF7  24H    B    C    D     C     E    C     C      C  ...       C
# 282      MCF7  24H    D    C    C     C     C    C     C      C  ...       C
# 283  A549.311  96H    D    C    C     C     D    D     D      B  ...       C
# 284  HT29.311  96H    D    C    C     B     A    C     C      C  ...       D
# 285  HT29.311  96H    B    C    A     C     C    C     D      C  ...       C
# 286  MCF7.311  96H    E    C    C     E     E    E     C      B  ...       C
# 287   PC3.101  96H    B    C    C     D     C    C     C      C  ...       C
# 288   PC3.101  96H    B    C    C     C     C    C     C      C  ...       C
# 289   PC3.311  96H    E    C    C     D     D    D     D      A  ...       C
# 290   PC3.311  96H    D    C    C     C     C    C     C      C  ...       C
# 291   PC3.311  96H    D    D    C     C     D    C     C      C  ...       C
# 292   PC3.311  96H    D    C    C     C     C    D     D      A  ...       C
# 293   PC3.311  96H    B    B    A     C     C    C     D      B  ...       C
#
#     SLC27A3 TBXA2R RTN2 TSTA3 PPARD GNA11 WDTC1 PLSCR3 NPEPL1
# 0         C      C    C     C     C     C     C      E      C
# 1         C      C    C     C     C     C     C      C      C
# 2         C      C    C     C     C     C     D      C      C
# 3         C      C    C     C     D     C     C      B      D
# 4         C      C    C     D     C     C     C      C      C
# 5         B      C    C     C     E     D     C      C      C
# 6         C      C    C     B     C     C     C      C      C
# 7         C      C    A     D     D     A     D      D      C
# 8         C      C    C     B     C     C     D      E      C
# 9         D      C    C     B     C     C     E      C      C
# 10        C      C    D     B     E     B     D      E      D
# 11        C      B    C     C     C     C     C      D      C
# 12        E      E    D     E     C     A     C      D      C
# 13        C      C    C     C     C     D     C      C      D
# 14        C      C    C     C     C     C     E      C      C
# 15        C      C    B     E     E     C     C      A      C
# 16        C      C    C     D     C     D     C      D      C
# 17        C      B    C     C     C     C     C      C      C
# 18        C      C    C     C     B     C     C      C      C
# 19        C      E    C     B     C     D     D      E      C
# 20        C      C    C     C     C     C     D      D      C
# 21        C      C    C     C     C     C     C      C      C
# 22        C      E    C     C     B     C     C      C      C
# 23        D      C    C     B     B     C     B      C      C
# 24        C      C    B     C     C     A     C      C      B
# 25        C      C    C     C     C     C     D      D      B
# 26        C      C    C     C     C     C     C      C      C
# 27        B      C    C     C     C     D     D      C      C
# 28        C      E    C     D     C     B     C      C      C
# 29        C      E    C     C     C     D     C      C      C
# ..      ...    ...  ...   ...   ...   ...   ...    ...    ...
# 264       C      C    A     C     C     C     C      C      C
# 265       E      C    C     C     C     C     C      C      C
# 266       D      C    C     C     C     C     B      E      C
# 267       E      C    C     B     C     C     C      C      C
# 268       E      C    D     B     D     C     B      B      E
# 269       C      C    C     C     B     D     C      C      C
# 270       E      B    B     C     C     C     E      C      C
# 271       C      E    C     C     D     C     C      D      C
# 272       E      C    C     C     C     C     E      C      C
# 273       B      C    C     C     C     C     C      D      C
# 274       C      D    C     A     C     C     C      C      C
# 275       E      E    E     B     E     C     A      A      E
# 276       C      C    D     B     C     C     C      C      C
# 277       C      C    C     A     D     C     C      B      C
# 278       B      C    B     D     C     D     C      C      D
# 279       E      D    C     C     D     C     C      C      D
# 280       C      D    C     A     E     C     C      E      E
# 281       C      E    D     B     C     C     D      D      D
# 282       C      C    C     C     C     C     C      D      A
# 283       C      D    C     C     C     C     C      C      C
# 284       E      C    C     C     C     C     E      E      C
# 285       C      C    C     D     C     C     E      C      D
# 286       C      C    C     C     E     C     C      D      B
# 287       E      C    C     C     C     A     C      C      C
# 288       D      B    C     C     C     C     C      C      C
# 289       C      C    C     B     D     C     E      C      E
# 290       C      E    C     C     C     C     C      C      C
# 291       C      C    C     C     C     C     B      C      C
# 292       C      E    C     C     D     C     E      C      D
# 293       C      E    C     D     C     C     C      C      D
#
# [294 rows x 980 columns]

# %%
dfc=df.CELL.value_counts()
dfc.plot(kind='bar')

# %%
sns.set_style('darkgrid')
sns.set(rc={'axes.facecolor':'.4', 'figure.facecolor':'.3'})

dfg=df.EGF.value_counts()
ax=dfg.plot(kind='bar',legend=True,color='r')
[i.set_color("red") for i in plt.gca().get_xticklabels()]
[i.set_color("k") for i in plt.gca().get_yticklabels()]
ax.get_yaxis().set_visible(False)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(20) 
    tick.label.set_fontweight('bold')
leg = plt.legend(framealpha = 0, loc = 'best')
for text in leg.get_texts():
    plt.setp(text, color = 'w',fontsize=24)

# %%
Z=['B','C']
str1='DDR1'

# %%
for val in Z:
    df=df[df.eval(str1) != val]
df
# Out:
#          CELL TIME DDR1 PAX8 RPS5 ABCF1 SPAG7 RHOA RNPS1 SMNDC1  ...   P4HTM  \
# 2       HEPG2  24H    E    C    D     C     C    D     C      C  ...       C
# 3      HS578T   3H    D    C    C     C     C    C     C      C  ...       D
# 4        HT29  24H    D    C    C     D     D    C     C      A  ...       E
# 5      MCF10A  24H    D    C    C     C     D    B     A      A  ...       D
# 6    MDAMB231  24H    E    C    D     B     B    C     A      B  ...       C
# 7      HCC515  24H    A    C    A     C     C    C     B      C  ...       C
# 9       HEPG2  24H    D    D    D     C     C    E     D      A  ...       E
# 10       HME1   3H    D    C    C     C     D    D     C      B  ...       D
# 11       HME1   3H    D    E    C     D     E    E     D      A  ...       E
# 12     HS578T  24H    E    C    C     C     D    A     B      C  ...       D
# 13       MCF7   3H    A    C    C     C     C    C     C      C  ...       C
# 15       A375  24H    E    E    B     C     D    B     A      B  ...       E
# 16     HCC515  24H    E    D    C     C     C    C     A      C  ...       C
# 17       HME1  24H    E    C    D     D     C    A     B      C  ...       E
# 18       HME1  24H    D    C    D     C     E    C     C      B  ...       E
# 19     JURKAT  24H    E    E    A     E     E    C     A      E  ...       E
# 21        PC3  24H    D    C    C     C     C    C     B      C  ...       C
# 22        PC3  24H    D    B    C     C     C    C     C      C  ...       C
# 24       CD34  24H    D    C    C     C     C    C     B      B  ...       D
# 26      HUVEC  24H    D    D    C     D     C    C     C      B  ...       C
# 27    NPC.TAK  24H    A    A    C     C     A    C     C      C  ...       A
# 29       A375  24H    D    C    E     C     D    B     B      A  ...       C
# 30      HEPG2  24H    E    C    C     D     C    C     C      D  ...       C
# 31        NEU  24H    D    E    D     C     C    C     A      D  ...       C
# 32       HT29  24H    D    C    C     D     C    D     D      B  ...       C
# 33      HUVEC  24H    D    D    C     C     A    A     C      E  ...       C
# 34       A375   6H    D    B    C     D     D    D     E      C  ...       B
# 35        NPC   6H    E    C    E     E     A    D     A      C  ...       C
# 36       HELA  24H    E    C    C     C     D    B     C      B  ...       C
# 37        PC3  24H    E    B    C     D     E    E     C      A  ...       C
# ..        ...  ...  ...  ...  ...   ...   ...  ...   ...    ...  ...     ...
# 71       HELA  24H    E    E    A     E     C    A     A      E  ...       B
# 72       MCF7  24H    D    C    C     D     D    E     C      A  ...       C
# 74       HA1E  24H    E    A    C     E     E    A     C      E  ...       B
# 75       MCF7  24H    D    C    C     C     C    C     C      C  ...       C
# 76       YAPC  24H    A    E    D     D     E    C     C      E  ...       A
# 77       HELA  24H    A    C    C     D     B    A     E      D  ...       C
# 78       MCF7  24H    A    C    C     E     E    A     A      D  ...       C
# 79       HELA  24H    A    C    C     D     B    C     C      E  ...       A
# 81       HA1E  24H    E    C    C     C     B    B     B      C  ...       E
# 82       HT29  24H    D    E    C     C     E    B     B      B  ...       C
# 83       A375  24H    E    C    A     E     E    E     C      A  ...       E
# 84       HA1E  24H    D    B    C     D     C    B     C      C  ...       B
# 85       HA1E  24H    D    C    C     D     D    E     E      A  ...       C
# 86       MCF7  24H    A    B    C     E     E    A     C      E  ...       B
# 87        PC3  24H    D    D    A     E     D    C     C      C  ...       C
# 88       HA1E  24H    E    A    C     E     E    A     E      E  ...       C
# 89       A375  24H    E    C    C     C     C    B     C      C  ...       C
# 91       HELA  24H    D    D    C     E     E    C     D      C  ...       C
# 94       HA1E  24H    E    B    C     E     E    A     C      E  ...       A
# 95       HA1E  24H    E    C    D     E     E    B     A      E  ...       A
# 96       MCF7  24H    A    C    B     E     E    A     A      E  ...       D
# 97       MCF7  24H    A    C    C     E     E    B     C      E  ...       C
# 98       YAPC  24H    A    C    E     E     E    C     C      E  ...       A
# 100      HT29  24H    E    C    B     D     C    C     C      C  ...       D
# 101       PC3  24H    D    C    B     C     C    C     D      C  ...       C
# 102      HA1E  24H    E    E    C     E     C    A     A      E  ...       A
# 103      HELA  24H    D    D    C     D     E    C     B      E  ...       C
# 104  MCF7.311  96H    E    C    C     E     E    E     C      B  ...       C
# 105   PC3.311  96H    D    D    C     C     D    C     C      C  ...       C
# 106   PC3.311  96H    D    C    C     C     C    D     D      A  ...       C
#
#     SLC27A3 TBXA2R RTN2 TSTA3 PPARD GNA11 WDTC1 PLSCR3 NPEPL1
# 2         B      C    C     C     E     D     C      C      C
# 3         C      C    A     D     D     A     D      D      C
# 4         C      C    C     B     C     C     D      E      C
# 5         C      C    D     B     E     B     D      E      D
# 6         E      E    D     E     C     A     C      D      C
# 7         C      C    C     C     C     C     D      D      B
# 9         B      C    C     C     C     D     D      C      C
# 10        C      E    C     D     C     B     C      C      C
# 11        C      D    C     B     D     B     E      B      A
# 12        D      C    D     C     C     B     C      A      D
# 13        C      D    C     A     C     B     C      C      B
# 15        D      E    D     C     E     C     E      E      D
# 16        D      D    C     C     E     A     C      E      D
# 17        E      D    C     C     A     B     C      B      C
# 18        C      C    C     C     C     B     E      E      C
# 19        E      E    E     A     C     E     A      E      E
# 21        C      D    C     B     C     C     C      C      E
# 22        C      C    C     C     C     C     E      C      D
# 24        C      C    C     C     C     C     C      C      C
# 26        E      C    C     B     D     C     D      C      D
# 27        B      E    E     C     E     E     E      B      E
# 29        C      D    C     C     D     B     C      D      C
# 30        B      C    C     D     B     D     C      C      C
# 31        C      C    D     D     C     C     C      B      E
# 32        B      C    C     C     C     D     C      C      C
# 33        C      D    C     A     C     C     E      C      B
# 34        D      D    C     C     C     C     C      D      D
# 35        E      E    D     E     E     A     E      B      E
# 36        D      C    D     C     C     C     E      C      E
# 37        D      C    C     A     E     C     C      C      D
# ..      ...    ...  ...   ...   ...   ...   ...    ...    ...
# 71        E      E    E     C     E     E     A      E      E
# 72        C      C    D     B     C     D     C      C      E
# 74        E      E    E     A     E     B     C      A      E
# 75        C      C    C     C     C     C     C      C      C
# 76        B      D    D     C     E     C     E      E      C
# 77        B      A    C     C     C     D     A      B      C
# 78        C      D    D     A     E     E     D      A      C
# 79        A      A    D     A     E     C     B      C      C
# 81        C      E    C     B     C     E     A      E      E
# 82        E      C    E     C     C     C     E      D      E
# 83        D      C    C     B     E     C     B      C      D
# 84        E      D    C     C     C     B     B      C      E
# 85        C      C    C     C     E     C     A      C      C
# 86        A      D    D     A     E     C     D      C      B
# 87        E      E    D     C     C     C     B      C      C
# 88        E      E    D     B     E     D     C      A      B
# 89        D      C    D     C     C     C     C      E      D
# 91        D      B    E     A     E     C     C      C      C
# 94        E      E    E     A     E     D     A      B      C
# 95        E      D    E     A     E     E     A      B      D
# 96        C      E    D     B     E     C     C      A      B
# 97        C      D    C     A     E     C     D      B      A
# 98        B      C    C     C     E     E     D      D      C
# 100       D      C    C     C     C     C     B      E      C
# 101       B      C    C     C     C     C     C      D      C
# 102       E      E    E     B     E     C     A      A      E
# 103       C      C    C     A     D     C     C      B      C
# 104       C      C    C     C     E     C     C      D      B
# 105       C      C    C     C     C     C     B      C      C
# 106       C      E    C     C     D     C     E      C      D
#
# [80 rows x 980 columns]

# %%
df.eval(str1)
# Out:
# 3      E
# 4      D
# 5      E
# 6      D
# 7      D
# 8      D
# 9      E
# 10     D
# 12     E
# 13     E
# 14     E
# 15     D
# 17     D
# 19     E
# 20     D
# 25     A
# 27     D
# 28     D
# 29     E
# 30     D
# 31     E
# 32     D
# 33     D
# 34     D
# 36     A
# 38     D
# 40     E
# 41     D
# 42     E
# 45     E
#       ..
# 257    D
# 258    E
# 259    A
# 260    D
# 262    D
# 264    E
# 265    D
# 266    E
# 267    D
# 268    E
# 269    D
# 270    D
# 271    D
# 272    D
# 273    D
# 274    E
# 275    E
# 276    D
# 277    D
# 278    D
# 279    D
# 280    E
# 282    D
# 283    D
# 284    D
# 286    E
# 289    E
# 290    D
# 291    D
# 292    D
# Name: DDR1, Length: 199, dtype: object

# %%
df.EGFR
# Out:
# 0      E
# 1      E
# 2      E
# 3      D
# 4      B
# 5      E
# 6      A
# 7      E
# 8      D
# 9      D
# 10     B
# 11     D
# 12     B
# 13     B
# 14     B
# 15     A
# 16     B
# 17     A
# 18     D
# 19     E
# 20     B
# 21     B
# 22     B
# 23     D
# 24     B
# 25     D
# 26     D
# 27     A
# 28     B
# 29     B
#       ..
# 77     E
# 78     D
# 79     E
# 80     D
# 81     E
# 82     B
# 83     D
# 84     B
# 85     E
# 86     D
# 87     B
# 88     E
# 89     E
# 90     D
# 91     E
# 92     B
# 93     A
# 94     A
# 95     B
# 96     D
# 97     E
# 98     A
# 99     D
# 100    B
# 101    B
# 102    A
# 103    D
# 104    E
# 105    B
# 106    D
# Name: EGFR, Length: 107, dtype: object

# %%
import operator
x = {1: 2, 3: 4, 4: 3, 2: 1, 0: 0}
sorted_x = sorted(x.items(), key=operator.itemgetter(1))

# %%
sorted_x[-1][1]
# Out:
# 4
